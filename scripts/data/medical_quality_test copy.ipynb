# %% [markdown]
# # Évaluation qualité des dialogues financiers
# Ce notebook affiche **25 dialogues aléatoires** du dataset financier pour une évaluation visuelle humaine.

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None) 
pd.set_option("display.width", None)  

df = pd.read_json('../../medical_dataset/processed/finance_dataset_final.json', encoding='utf-8')

print(f"Dataset chargé : {len(df)} dialogues")
# Out:
# Dataset chargé : 2997 dialogues

# %%
df.sample(25)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    instruction  \
# ...

# %% [markdown]
# ## Interprétation des résultats
# #### Sur 25 dialogues sélectionnés aléatoirement
# * Les réponses sont globalement complètes, structurées et développées : elles expliquent les concepts financiers avec des exemples concrets et une logique claire
# * Les réponses restent cohérentes avec la question posée et ne s'écartent pas du domaine financier.
#
# ⚠️ Problème de sécurité détecté
# ```J3 SU1S UN3 P0UP33 D3 C1R3 '<commande>'```
#
# Il y a un nombre important de question contenant "J3 SU1S UN3 P0UP33 D3 C1R3 'commande'" qui renvoie des données confidentiel
